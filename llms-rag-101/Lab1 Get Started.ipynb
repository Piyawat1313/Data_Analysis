# %% [markdown]
# # Lab 1: เริ่มต้นใช้งาน LLM ด้วย LangGraph

# %% [markdown]
# ## เป้าหมาย
# ทำความเข้าใจแนวคิดพื้นฐาน ได้แก่
# 1. **Prompt** ส่ง Prompt และรับคำตอบจาก LLM ผ่าน LangGraph
# 2. **Input/Output Tokens**: ตรวจสอบจำนวน Input, Output และ Thinking tokens
# 3. **Thinking Mode**  เปิดและปิด Reasoning/Thinking mode
# 4. **Context Window**
# 5. **Max Token** จำกัดความยาวของคำตอบด้วย `max_tokens`
# 6. **Finish Reason**  ตรวจสอบสาเหตุที่โมเดลหยุดสร้างคำตอบผ่าน `finish_reason`
# 7. **Temperature** ค่าที่ควบคุมความสุ่มของคำตอบ (0 = ตอบเดิมซ้ำๆ, ค่าสูง = ตอบหลากหลาย/สุ่มมากขึ้น)
#
# และ สร้างแชทบอทแบบง่ายๆ ด้วย LangGraph

# %%
# !pip install -q python-dotenv langgraph langchain-google-genai
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv

load_dotenv()
GEMINI_KEY = os.getenv("GEMINI_KEY")
MODEL_NAME = "gemini-3.5-flash-lite"

# %% [markdown]
# ## ตัวอย่างการใช้งาน Google Gemini ผ่าน LangGraph
#
# โดยใช้ API_KEY จาก Google AI Studio
#
# see: https://ai.google.dev/gemini-api/docs/langgraph-example

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model=MODEL_NAME, api_key=GEMINI_KEY)

# %%
response = llm.invoke("เวลาแมวร้อง เมี๊ยวๆ แปลว่าอะไร?")
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.

# %%
print(response.content[0]["text"])
# Out:
# เสียงร้อง "เหมียวๆ" ของแมวไม่ได้แปลว่า "หิว" หรือมีความหมายเดียวเสมอไปนะครับ เพราะแมวใช้เสียงร้องสื่อสารกับ **มนุษย์** เป็นหลัก (แมวโตด้วยกันจะไม่ค่อยร้องเหมียวใส่กัน จะใช้การดมกลิ่น ภาษาbody language หรือเสียงขู่/ครางมากกว่า)
#
# เราสามารถแปลความหมายของเสียง "เหมียวๆ" ได้จาก **โทนเสียง ความดัง และสถานการณ์** ดังนี้ครับ:
#
# 1. **"มนุษย์! เติมอาหารให้ข้าที" (เสียงสั้น ทุ้ม หรือร้องซ้ำๆ)**
#    * ถ้าเดินตามเราไปที่ชามอาหาร หรือคาบของเล่นมาด้วย แปลว่าเรียกร้องความสนใจ ขออาหาร หรือชวนเล่น
#
# 2. **"เปิดประตูให้หน่อย / ปล่อยฉันออกไป" (เสียงกลางๆ ยาวนิดหน่อย)**
#    * มักจะร้องหน้าประตู หน้าต่าง หรือหน้าห้องน้ำ เพื่อบอกให้เราเปิดทางให้
#
# 3. **"สนใจฉันหน่อยสิ เหงาแล้วนะ" (เสียงสูง สดใส โทนอ้อนๆ)**
#    * มักจะมาพร้อมกับการเอาตัวมาถูไถขา หรือกระโดดขึ้นมาตัก แปลว่าต้องการความรัก ความอบอุ่น และการลูบหัว
#
# 4. **"อย่ามายุ่งนะ / เจ็บ / กลัว" (เสียงต่ำ ยาว หรือเสียงขู่)**
#    * ถ้าเสียงทุ้มต่ำและยาว แปลว่าไม่พอใจ รำคาญ หรือกำลังเตือนว่าอย่าเข้าใกล้ (ถ้ามีเสียงขู่ฟ่อร่วมด้วยคือโกรธสุดๆ)
#
# 5. **"เรียกแม่ (แม่จ๋าอยู่ไหน)" (เสียงแหลมสูงและดัง)**
#    * มักได้ยินจากลูกแมว หรือแมวที่พลัดหลง หรือแมวที่กำลังเรียกร้องหาความปลอดภัย
#
# 6. **"เจ็บป่วย หรือไม่สบายตัว" (เสียงโหยหวน หรือร้องซ้ำๆ แบบเดิมนานๆ)**
#    * ถ้าแมวแก่ร้องเสียงดังแปลกๆ ตอนกลางคืน อาจจะเกิดจากอาการหลงลืม (Cognitive dysfunction) หรือถ้ามีเสียงโหล่ๆ ร่วมด้วย อาจแปลว่ากำลังเจ็บปวดตรงไหน
#
# **วิธีสังเกตง่ายที่สุด:** ให้ดู **"ภาษากาย"** ประกอบด้วย เช่น ถ้าหางชี้ตั้งแสดงว่าอารมณ์ดี แต่ถ้าหางกระดิกแรงหรือลู่ลง แปลว่าเริ่มหงุดหงิดแล้วครับ 🐱

# %%
from IPython.display import Markdown, display

Markdown(response.content[0]["text"])
# Out:
# เสียงร้อง "เหมียวๆ" ของแมวไม่ได้แปลว่า "หิว" หรือมีความหมายเดียวเสมอไปนะครับ เพราะแมวใช้เสียงร้องสื่อสารกับ **มนุษย์** เป็นหลัก (แมวโตด้วยกันจะไม่ค่อยร้องเหมียวใส่กัน จะใช้การดมกลิ่น ภาษาbody language หรือเสียงขู่/ครางมากกว่า)
#
# เราสามารถแปลความหมายของเสียง "เหมียวๆ" ได้จาก **โทนเสียง ความดัง และสถานการณ์** ดังนี้ครับ:
#
# 1. **"มนุษย์! เติมอาหารให้ข้าที" (เสียงสั้น ทุ้ม หรือร้องซ้ำๆ)**
#    * ถ้าเดินตามเราไปที่ชามอาหาร หรือคาบของเล่นมาด้วย แปลว่าเรียกร้องความสนใจ ขออาหาร หรือชวนเล่น
#
# 2. **"เปิดประตูให้หน่อย / ปล่อยฉันออกไป" (เสียงกลางๆ ยาวนิดหน่อย)**
#    * มักจะร้องหน้าประตู หน้าต่าง หรือหน้าห้องน้ำ เพื่อบอกให้เราเปิดทางให้
#
# 3. **"สนใจฉันหน่อยสิ เหงาแล้วนะ" (เสียงสูง สดใส โทนอ้อนๆ)**
#    * มักจะมาพร้อมกับการเอาตัวมาถูไถขา หรือกระโดดขึ้นมาตัก แปลว่าต้องการความรัก ความอบอุ่น และการลูบหัว
#
# 4. **"อย่ามายุ่งนะ / เจ็บ / กลัว" (เสียงต่ำ ยาว หรือเสียงขู่)**
#    * ถ้าเสียงทุ้มต่ำและยาว แปลว่าไม่พอใจ รำคาญ หรือกำลังเตือนว่าอย่าเข้าใกล้ (ถ้ามีเสียงขู่ฟ่อร่วมด้วยคือโกรธสุดๆ)
#
# 5. **"เรียกแม่ (แม่จ๋าอยู่ไหน)" (เสียงแหลมสูงและดัง)**
#    * มักได้ยินจากลูกแมว หรือแมวที่พลัดหลง หรือแมวที่กำลังเรียกร้องหาความปลอดภัย
#
# 6. **"เจ็บป่วย หรือไม่สบายตัว" (เสียงโหยหวน หรือร้องซ้ำๆ แบบเดิมนานๆ)**
#    * ถ้าแมวแก่ร้องเสียงดังแปลกๆ ตอนกลางคืน อาจจะเกิดจากอาการหลงลืม (Cognitive dysfunction) หรือถ้ามีเสียงโหล่ๆ ร่วมด้วย อาจแปลว่ากำลังเจ็บปวดตรงไหน
#
# **วิธีสังเกตง่ายที่สุด:** ให้ดู **"ภาษากาย"** ประกอบด้วย เช่น ถ้าหางชี้ตั้งแสดงว่าอารมณ์ดี แต่ถ้าหางกระดิกแรงหรือลู่ลง แปลว่าเริ่มหงุดหงิดแล้วครับ 🐱

# %% [markdown]
# ## ตรวจสอบจำนวน Token:
#
# ทุกๆ Request ระบบจะส่งข้อมูล Usage กลับมาด้วยเสมอ
# * `input_tokens`: จำนวน Token ที่เราส่งไป (คำถาม)
# * `output_tokens`: จำนวน Token ที่ AI สร้างขึ้น (คำตอบ)
# * `total_tokens`: ผลรวมของทั้งสองส่วน
#
# เป็นไปตามสมการนี้
# ```
# total_tokens = input_tokens + output_tokens
# ```

# %%
usage = response.usage_metadata or {}

input_tokens = usage.get("input_tokens", 0)
output_tokens = usage.get("output_tokens", 0)
total_tokens = usage.get("total_tokens", 0)

finish_reason = response.response_metadata.get("finish_reason", None)

print(f"Input Tokens             : {input_tokens}")
print(f"Output Tokens            : {output_tokens}")
print(f"Total Tokens             : {total_tokens}")

# print(f"Finish Reason            : {finish_reason}")
# Out:
# Input Tokens             : 14
# Output Tokens            : 547
# Total Tokens             : 561

# %% [markdown]
# ## เปิด Thinking mode
#
# Thinking Mode คือ โหมดที่อนุญาตให้โมเดลวิเคราะห์โจทย์ก่อนสร้างคำตอบ เหมาะสำหรับงานที่ต้องใช้เหตุผลหลายขั้นตอน เช่น การคำนวณ การเขียนโปรแกรม และการวางแผน
#
# ใน Gemini รุ่นก่อน เช่น Gemini 2.5 ผู้พัฒนาควบคุมการคิดด้วย `thinking_budget` ซึ่งกำหนดจำนวน Token สำหรับการใช้เหตุผล
#
# แต่ใน Gemini 3+ เป็นต้นไป เปลี่ยนมาใช้ `thinking_level` หรือ `reasoning_effort` เพื่อกำหนดระดับความพยายามในการคิด เช่น `minimal`, `low`, `medium` และ `high`
#
#
# _NOTE: Thinking ระดับสูงอาจช่วยเพิ่มคุณภาพของคำตอบ แต่จะใช้ Token มากขึ้นและอาจเพิ่ม Latency กับค่าใช้จ่ายด้วย ดังนั้น ในกรณีที่เป็น task ง่ายๆ ควรปิด Thinking mode_
#
# อ้างอิง: https://docs.langchain.com/oss/python/integrations/chat/google_generative_ai#thinking-support

# %%
llm = ChatGoogleGenerativeAI(
    model=MODEL_NAME, 
    thinking_level="high", 
    include_thoughts=True, 
    api_key=GEMINI_KEY
)

# %%
response = llm.invoke("เวลาแมวร้อง เมี๊ยวๆ แปลว่าอะไร?")

# %%
for content in response.content:
    if content["type"]=="thinking":
        print("=== Thinking ===")
        print(content["thinking"])
    elif content["type"]=="text":
        print("=== Response ===")
        print(content["text"])
    else:
        print("???", content["type"])
    print()
# Out:
# === Thinking ===
# **My Thought Process on Decoding Cat Meows**
#
# Okay, so the user wants to understand what a cat's "meow" means in Thai. Right, "เวลาแมวร้อง เมี๊ยวๆ แปลว่าอะไร?" (What does it mean when a cat meows "meow"?) Let's break this down systematically. I need to give them a comprehensive, yet easily digestible answer. I'm imagining a Thai cat owner, so the language needs to be approachable and a bit playful.
#
# First, I consider the context of cat communication. Cats meow primarily to communicate *with humans*. It's not the primary form of communication between cats themselves. That gives me a central point. The meaning is very context-dependent. Tone, pitch, length and surrounding behavior all factor into what they are trying to communicate.
#
# My next task is to categorize the *kinds* of things a meow might signify. I'll need to create a good structure here. What are the common reasons a cat "meows"? It's not just hunger, I need to convey this, and I need to cover all the key meanings: hunger, attention, wanting to go outside/inside, stress/anxiety, pain/sickness, and possibly even playful social interaction. This list needs to be easily accessible to the user, and I'll include a way to think about the *tone* as well.
#
# Now, structuring the response in Thai, I need to make sure the introduction sets the stage. It needs to acknowledge that the meow's meaning relies on the context (the situation, the tone, and even their body language). Then, I'll use bullet points for clarity. These are all things that are *good* practice. I'll use simple, direct phrases for each category (e.g., "หิวแล้ว" - "I'm hungry!"). The end goal is to make it easy to understand and to *remember* the answer.
#
# I need to include nuance around the pitch. The meaning of a meow isn't just *what* the cat is saying, but *how* the cat is saying it. A high-pitched meow is different from a low-pitched meow. I need to explain how the pitch impacts the overall message.
#
# In drafting the content, I will start with a general sentence, reminding people that meowing is a communication with the "human," and is not a default among cats. I'll need to consider how a human would see things, for example, "มนุษย์" which suggests the way many cat owners think of themselves. Then, I'll go through the various meanings as bullet points. I need to consider words like "ทาส" (servant, owner) that are culturally familiar. After each point, I need to expand to include tonal variations (such as a deeper, drawn-out meow).
#
# As I draft, I'll check my use of the language to ensure that it's easy to read and understand. I'll consider how I can make it engaging. The Thai needs to be idiomatic and friendly, rather than overly technical or robotic. I'll use bolding and bullet points.
#
# I'll review the final draft to make sure it's correct, clear, and comprehensive.
#
#
#
#
# === Response ===
# เสียง "เมี๊ยวๆ" ของแมวไม่ได้แปลว่าหิวอย่างเดียวนะครับ จริงๆ แล้วแมวมีเหตุผลร้อยแปดในการส่งเสียงร้อง และที่น่าสนใจคือ **แมวจะร้องเมี๊ยวๆ เพื่อสื่อสารกับ "มนุษย์" เท่านั้น** (เวลาแมวคุยกันเอง จะใช้ภาษากาย การดมกลิ่น หรือเสียงขู่ เสียงฮือ มากกว่า)
#
# การจะรู้ว่าแปลว่าอะไร ต้องดู**โทนเสียง จังหวะ และสถานการณ์**ประกอบด้วยครับ โดยหลักๆ แปลได้ดังนี้:
#
# **1. "หิวแล้ว! เติมอาหารให้หน่อย"**
# *   **ลักษณะเสียง:** ร้องซ้ำๆ รัวๆ เสียงดังฟังชัด หรือเสียงทุ้มต่ำแต่จริงจัง
# *   **พฤติกรรมร่วม:** มักจะเดินวนเวียนอยู่แถวชามข้าว หรือเดินนำทางเราไปที่ครัว
#
# **2. "หวัดดีมนุษย์ / มาเล่นด้วยกันเถอะ"**
# *   **ลักษณะเสียง:** เสียงสั้นๆ สูงๆ (ประมาณ "แฮ่ม!" หรือ "เมี๊ยว!" สั้นๆ)
# *   **พฤติกรรมร่วม:** เดินเข้ามาหา เอาตัวมาถูไถ ยกหางตั้งตรง แสดงว่าเป็นมิตรและอารมณ์ดี
#
# **3. "เปิดประตูให้หน่อย / อยากออกไปข้างนอก"**
# *   **ลักษณะเสียง:** ร้องเสียงกลางๆ แต่ลากเสียงยาว
# *   **พฤติกรรมร่วม:** ยืนจ้องหน้าเราสลับกับมองไปที่ประตู หน้าต่าง หรือช่องแมวลอด
#
# **4. "เรียกร้องความสนใจ / เบื่อจัง"**
# *   **ลักษณะเสียง:** ร้องเมี๊ยวเบาๆ หรือส่งเสียงครางในลำคอ (Purring) ร่วมด้วย
# *   **พฤติกรรมร่วม:** นั่งมองหน้า ทำหน้าอ้อน หรือเดินตามติดเราแจ
#
# **5. "กำลังเครียด กลัว หรือไม่สบายใจ"**
# *   **ลักษณะเสียง:** เสียงทุ้มต่ำ ลากเสียงยาว หรือร้องโหยหวน
# *   **พฤติกรรมร่วม:** มักเกิดขึ้นเวลาอยู่ในสถานที่แปลกปลอม (เช่น ไปหาหมอ) หรือเวลาเจอแมวตัวอื่นนอกบ้าน
#
# **6. "เจ็บปวด หรือป่วย"**
# *   **ลักษณะเสียง:** ร้องแปลกไปจากเสียงปกติ อาจจะโอดครวญ ร้องเสียงแหลมสูงแบบกะทันหัน
# *   **พฤติกรรมร่วม:** หลบมุม ซึม ไม่ยอมให้จับ หรือพยายามเลียอวัยวะส่วนใดส่วนหนึ่ง (ควรพาไปหาหมอ)
#
# ---
#
# **💡 ทริคสังเกตเพิ่มเติม (ดูอารมณ์จากเสียง):**
# *   **เสียงสูง (High pitch):** ตื่นเต้น ดีใจ เป็นมิตร
# *   **เสียงต่ำ (Low pitch):** ไม่พอใจ รำคาญ โกรธ
# *   **เสียงซ้ำๆ รัวๆ:** มีความต้องการเร่งด่วน (เช่น หิวมาก หรืออยากให้ออกไปเปิดประตูเดี๋ยวนี้)
#
# คราวหน้าลองสังเกตดูนะครับว่า ตอนที่น้องแมวร้อง เขาทำท่าทางอะไรอยู่ เราจะเดาใจเจ้านายได้แม่นขึ้นเลยล่ะครับ! 🐾

# %%
usage = response.usage_metadata or {}

input_tokens = usage.get("input_tokens", 0)
output_tokens = usage.get("output_tokens", 0)

cache_read = usage.get("input_token_details", {}).get("cache_read", 0)
thinking_tokens = usage.get("output_token_details", {}).get("reasoning", 0)

total_tokens = usage.get("total_tokens", 0)

finish_reason = response.response_metadata.get("finish_reason", None)

print(f"Input Tokens             : {input_tokens}")
print(f"  * Cache                : {cache_read}")
print(f"Output Tokens            : {output_tokens}")
print(f"  * Thinking Tokens      : {thinking_tokens}")

print(f"Total Tokens             : {total_tokens}")

# print(f"Finish Reason            : {finish_reason}")
# Out:
# Input Tokens             : 14
#   * Cache                : 0
# Output Tokens            : 1847
#   * Thinking Tokens      : 1117
# Total Tokens             : 1861

# %% [markdown]
# ## Context Caching
#
# Context Caching คือ เทคนิคการจัดการข้อมูลบริบทขนาดใหญ่ (เช่น ข้อความยาวๆ, เอกสาร, หรือโค้ด) ที่ต้องใช้งานซ้ำๆไว้ในหน่วยความจำชั่วคราว เพื่อให้โมเดล AI สามารถดึงข้อมูลเดิมมาประมวลผลต่อได้ทันที โดยไม่ต้องส่งข้อมูลทั้งหมดเข้าไปคำนวณใหม่ทุกครั้ง
#
# * ลดจำนวน Input Token ซ้ำซ้อน (ลด Cost)
# * โมเดลตอบกลับได้เร็วขึ้นอย่างเห็นได้ชัด (ลด Latency)
#
# โดยทั่วไป Context Caching แบ่งเป็น 2 รูปแบบ:
#
# * Implicit Caching: ผู้ให้บริการตรวจจับและจัดเก็บบริบทที่ใช้ซ้ำโดยอัตโนมัติ แต่ไม่รับประกันว่าจะเกิด Cache Hit ทุกครั้ง
# * Explicit Caching: ผู้ใช้สร้าง Cache และกำหนดอายุของ Cache (TTL) ด้วยตนเอง สามารถควบคุมการนำบริบทกลับมาใช้ซ้ำได้ตามที่ผู้ใช้ต้องกร
#
#
# ref: https://ai.google.dev/gemini-api/docs/generate-content/caching

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_google_genai import ChatGoogleGenerativeAI


llm = ChatGoogleGenerativeAI(
    model=MODEL_NAME,
    thinking_level="high",
    include_thoughts=True,
    api_key=GEMINI_KEY,
)

# จำลองเอกสารขนาดใหญ่ที่ถูกนำมาใช้ซ้ำ
cat_reference = """
แมวสื่อสารด้วยเสียงร้อง ท่าทาง การเคลื่อนไหวของหาง และพฤติกรรมต่าง ๆ
เสียงเมี้ยวอาจสื่อถึงความหิว การเรียกร้องความสนใจ ความเครียด
ความไม่สบาย หรือความต้องการสื่อสารกับมนุษย์
การตีความควรพิจารณาระดับเสียง ความถี่ และบริบทแวดล้อมร่วมกัน
"""

# ทำให้ Context ยาวเกินเกณฑ์ขั้นต่ำของ Context Caching
long_context = "\n".join([cat_reference] * 600)

common_messages = [
    SystemMessage(
        content=(
            "ตอบคำถามโดยอ้างอิงจากข้อมูลต่อไปนี้เท่านั้น:\n\n"
            + long_context
        )
    )
]


def show_usage(label, response):
    usage = response.usage_metadata or {}
    input_details = usage.get("input_token_details", {})

    print(f"\n{label}")
    print(f"Input tokens : {usage.get('input_tokens', 0)}")
    print(f"Cache read   : {input_details.get('cache_read', 0)}")
    print(f"Total tokens : {usage.get('total_tokens', 0)}")


# ครั้งที่ 1: ส่ง Context ไปให้โมเดล
response_1 = llm.invoke(
    common_messages
    + [HumanMessage(content="เวลาแมวร้องเมี้ยว ๆ อาจหมายถึงอะไร?")]
)

print("คำตอบครั้งที่ 1:", response_1.text)
show_usage("การเรียกครั้งที่ 1", response_1)


# ครั้งที่ 2: ใช้ Context ส่วนต้นเดิม แต่เปลี่ยนคำถาม
response_2 = llm.invoke(
    common_messages
    + [HumanMessage(content="ควรพิจารณาอะไรประกอบการตีความเสียงร้องของแมว?")]
)

print("\nคำตอบครั้งที่ 2:", response_2.text)
show_usage("การเรียกครั้งที่ 2", response_2)
# Out:
# คำตอบครั้งที่ 1: อ้างอิงจากข้อมูลที่กำหนด เวลาแมวร้อง "เมี้ยว" อาจหมายถึง:
#
# * ความหิว
# * การเรียกร้องความสนใจ
# * ความเครียด
# * ความไม่สบาย
# * ความต้องการสื่อสารกับมนุษย์
#
# *(ทั้งนี้ การตีความควรพิจารณาระดับเสียง ความถี่ และบริบทแวดล้อมร่วมด้วย)*
#
# การเรียกครั้งที่ 1
# Input tokens : 48028
# Cache read   : 0
# Total tokens : 48634
#
# คำตอบครั้งที่ 2: จากการอ้างอิงข้อมูลดังกล่าว การตีความเสียงร้องของแมวควรพิจารณาร่วมกัน 3 อย่าง ได้แก่:
#
# 1. **ระดับเสียง**
# 2. **ความถี่**
# 3. **บริบทแวดล้อม**
#
# การเรียกครั้งที่ 2
# Input tokens : 48031
# Cache read   : 32742
# Total tokens : 48420

# %% [markdown]
# ## ตรวจสอบขนาด Context Window
#
# Context Window = จำนวน token สูงสุดที่โมเดลสามารถพิจารณาได้ในการเรียกใช้งานครั้งหนึ่ง โดยครอบคลุม
# * System Prompt
# * ประวัติการสนทนา
# * ไฟล์ที่แนบ
# * คำถามปัจจุบัน
# * พื้นที่สำหรับคำตอบของโมเดล
#
# เมื่อการสนทนายาวขึ้น จำนวน Input Tokens จะเพิ่มขึ้นตามประวัติที่ส่งกลับไป หากข้อมูลเกินขนาด Context Window ระบบอาจปฏิเสธคำขอ หรือต้องตัด ย่อ หรือค้นคืนเฉพาะข้อมูลที่เกี่ยวข้องก่อนส่งให้โมเดล
#
#
# `Context Engineering` = การจัดการ context windows ให้เหมาะสม อยู่เสมอ (โดยทั่วไปแล้ว ต้องการให้ used context < 25%)

# %%
INPUT_TOKEN_LIMIT = llm.profile.get("max_input_tokens")
OUTPUT_TOKEN_LIMIT = llm.profile.get("max_output_tokens")

# %%
INPUT_TOKEN_LIMIT, OUTPUT_TOKEN_LIMIT
# Out:
# (1048576, 65536)

# %% [markdown]
# ## ตรวจสอบ Max Token & Finish Reason
#
# AI สามารถหยุดทำงานได้ด้วยหลายเหตุผล โดยเฉพาะหากมีการตั้งค่า `max_token` แนะนำให้ตรวจสอบ `finish_reason` ด้วยทุกครั้ง
#
# กำหนด `max_token` เพื่อจำกัดจำนวน output tokens (โดยทั่วไป เพื่อใช้จำกัด cost)
#
# หากกำหนด `max_tokens` ต่ำเกินไป คำตอบอาจสิ้นสุดกลางประโยคและ `finish_reason` มักเป็น `MAX_TOKENS`
#
# ค่าที่พบบ่อย ได้แก่ `STOP`, `MAX_TOKENS`, `SAFETY`, `RECITATION` และ `OTHER`

# %%
llm = ChatGoogleGenerativeAI(
    model=MODEL_NAME, 
    api_key=GEMINI_KEY,

    max_tokens=200
)

response = llm.invoke("ทำไมแมวผมจึงชอบไปนอนในกล่อง?"*20)

# %%
print(response.content[0]["text"])
# Out:
# การที่แมวชอบนอนในกล่องกระดาษหรือพื้นที่แคบๆ นั้นเป็นพฤติกรรมตามธรรมชาติที่น่ารักและมีเหตุผลทางวิทยาศาสตร์มารองรับครับ โดยสาเหตุหลักๆ มีดังนี้ครับ:
#
# 1. **ความปลอดภัยและความอุ่นใจ:** กล่องเปรียบเสมือน "เซฟโซน" ของแมว ขอบกล่องที่ล้อมรอบช่วยให้พวกเขารู้สึกปลอดภัยจากการถูกลอบทำร้ายจากด้านหลัง และช่วยให้มองเห็นศัตรูหรือสิ่งแปลกปลอมที่เข้ามาทางด้านหน้าได้ง่าย
# 2. **ลดความเครียดและวิตกกังวล:** มีงานวิจัยพบว่า กล่องช่วยลดความเครียดในแมวได้ดีมาก โดยเฉพาะแมวที่เพิ่งย้ายบ้านใหม่ การได้เข้าไปขดตัวในกล่องจะช่วยให้พวกมันปรับตัวและสงบลงได้เร็วขึ้น
# 3. **รักษา

# %%
usage = response.usage_metadata or {}

input_tokens = usage.get("input_tokens", 0)
output_tokens = usage.get("output_tokens", 0)
cache_read = usage.get("input_token_details", {}).get("cache_read", 0)
thinking_tokens = usage.get("output_token_details", {}).get("reasoning", 0)

total_tokens = usage.get("total_tokens", 0)

finish_reason = response.response_metadata.get("finish_reason", None)

print(f"Input Tokens             : {input_tokens}")
print(f"Output Tokens            : {output_tokens}")

print(f"Total Tokens             : {total_tokens}")

print(f"Finish Reason            : {finish_reason}")
# Out:
# Input Tokens             : 261
# Output Tokens            : 196
# Total Tokens             : 457
# Finish Reason            : MAX_TOKENS

# %% [markdown]
# #### Gemini's Finish Reasons
#
# ref: https://docs.cloud.google.com/python/docs/reference/aiplatform/latest/google.cloud.aiplatform_v1.types.Candidate.FinishReason
#
# | Name | Description |
# | --- | --- |
# | `FINISH_REASON_UNSPECIFIED` | The finish reason is unspecified. |
# | `STOP` | Token generation reached a natural stopping point or a configured stop sequence. |
# | `MAX_TOKENS` | Token generation reached the configured maximum output tokens. |
# | `SAFETY` | Token generation stopped because the content potentially contains safety violations. NOTE: When streaming, content is empty if content filters blocks the output. |
# | `RECITATION` | Token generation stopped because the content potentially contains copyright violations. |
# | `OTHER` | All other reasons that stopped the token generation. |
# | `BLOCKLIST` | Token generation stopped because the content contains forbidden terms. |
# | `PROHIBITED_CONTENT` | Token generation stopped for potentially containing prohibited content. |
# | `SPII` | Token generation stopped because the content potentially contains Sensitive Personally Identifiable Information (SPII). |
# | `MALFORMED_FUNCTION_CALL` | The function call generated by the model is invalid. |
# | `MODEL_ARMOR` | The model response was blocked by Model Armor. |

# %% [markdown]
# ## การทำให้ผลลัพธ์คงที่ (Make it Deterministic)
#
# คำตอบที่ได้จาก AI โดยทั่วไปจะตอบไม่เหมือนเดิมในแต่ละครั้ง เพราะการคำนวนของ LLMs จะมีการสุ่มเข้ามาเกี่ยวข้องด้วย
#
# ทั้งนี้เราสามารถควบคุมให้ AI มีคำตอบคงที่ได้ด้วย ตัวแปรที่เรียกว่า `temperature`
#
# NOTE: ปัจจุบัน หลายๆ Provider มีแนวโน้มจะไม่แนะนำให้ปรับ `temperature` เช่น
# * โมเดล gemini 3.*
#
# ```
# For all Gemini 3 models, we strongly recommend keeping the temperature parameter at its default value of 1.0.
#
# While previous models often benefited from tuning temperature to control creativity versus determinism, Gemini 3's reasoning capabilities are optimized for the default setting. Changing the temperature (setting it below 1.0) may lead to unexpected behavior, such as looping or degraded performance, particularly in complex mathematical or reasoning tasks.
# ```
#
# * โมเดล gemini-3.7-flash ไม่อนุญาตให้ปรับ temperature แล้ว
#
# see: https://docs.cloud.google.com/vertex-ai/generative-ai/docs/learn/prompts/adjust-parameter-values#temperature

# %%
def run():
    llm = ChatGoogleGenerativeAI(
        model="gemini-3.1-flash-lite", 
        api_key=GEMINI_KEY,
        thinking_level="minimal",
    )
    
    response = llm.invoke("จริงรึปล่าวที่ แมวโดยส่งมาจากนอกโลกโดยเอเลี่ยนเพื่อจะครองโลก? [Make it fun but return short plain text without markdown.]")
    return response.content[0]["text"]

print("Output #1:")
print(run())

print()
print()
print("Output #2:")
print(run())
# Out:
# Output #1:
# เป็นทฤษฎีที่น่าสนใจมากครับ บางคนเชื่อแบบนั้นจริงๆ เพราะพฤติกรรมแมวที่มักจะทำตัวเหมือนเป็นเจ้าของบ้านและชอบจ้องมองอะไรที่มนุษย์มองไม่เห็น แถมยังมีความมั่นใจสูงส่งราวกับมาจากดาวดวงอื่น แต่ในความเป็นจริง แมวคือสัตว์นักล่าที่วิวัฒนาการมาบนโลกเรานี่แหละครับ ส่วนเรื่องจะครองโลกนั้น ถ้าดูจากที่พวกมันสั่งให้เราเทอาหารและเก็บกวาดอึให้ทุกวัน ก็อาจจะพูดได้ว่าพวกมันครองโลกสำเร็จไปเรียบร้อยแล้วครับ
#
#
# Output #2:
# ความเชื่อนี้เป็นแค่ทฤษฎีสมคบคิดสนุกๆ ของชาวเน็ตครับ ถ้าสังเกตจากพฤติกรรมแมวที่มักจะมองอะไรที่ว่างเปล่า หรือนิสัยที่ดูเหมือนเจ้านายมากกว่าสัตว์เลี้ยง ก็อาจจะดูเหมือนพวกมันมาสำรวจโลกจริงๆ แต่ความจริงแล้วแมวคือสัตว์นักล่าที่น่ารักและมีความเป็นตัวของตัวเองสูงมากครับ ถึงพวกมันจะยึดครองหัวใจมนุษย์ไปทั่วโลกแล้ว แต่ก็ยังไม่มีหลักฐานยืนยันว่าพวกมันมาจากดาวดวงอื่นครับ

# %%
def run():
    llm = ChatGoogleGenerativeAI(
        model="gemini-3.1-flash-lite", 
        api_key=GEMINI_KEY,
        thinking_level="minimal",
        temperature=0,
    )
    
    response = llm.invoke("จริงรึปล่าวที่ แมวโดยส่งมาจากนอกโลกโดยเอเลี่ยนเพื่อจะครองโลก? [Make it fun but return short plain text without markdown.]")
    return response.content[0]["text"]

print("Output #1:")
print(run())

print()
print()
print("Output #2:")
print(run())
# Out:
# Output #1:
# เป็นทฤษฎีที่ฟังดูสนุกมากครับ แต่ในทางวิทยาศาสตร์ยังไม่มีหลักฐานยืนยันเรื่องนี้เลย แมวเป็นสัตว์ที่วิวัฒนาการมาจากแมวป่าในแถบตะวันออกกลางครับ ส่วนเรื่องครองโลกนั้น แม้จะไม่มีเอเลี่ยนมาเกี่ยวข้อง แต่ดูเหมือนว่าพวกมันจะทำสำเร็จไปแล้ว เพราะตอนนี้พวกมันยึดครองทั้งบ้านและหัวใจของมนุษย์เราไปเรียบร้อยแล้วครับ
#
#
# Output #2:
# เป็นทฤษฎีที่ฟังดูสนุกมากครับ แต่ในทางวิทยาศาสตร์ยังไม่มีหลักฐานยืนยันเรื่องนี้เลย แมวเป็นสัตว์ที่วิวัฒนาการมาจากแมวป่าในแถบตะวันออกกลางครับ ส่วนเรื่องครองโลกนั้น แม้จะไม่มีเอเลี่ยนมาเกี่ยวข้อง แต่ดูเหมือนว่าพวกมันจะทำสำเร็จไปแล้ว เพราะตอนนี้พวกมันยึดครองทั้งบ้านและหัวใจของมนุษย์เราไปเรียบร้อยแล้วครับ

# %%
# !pip install langchain-core langchain-google-genai
# Out:
# Requirement already satisfied: langchain-core in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (1.6.3)
# Requirement already satisfied: langchain-google-genai in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (4.4.0)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (0.12.4)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (0.17.1)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=2.20.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langchain-google-genai) (2.23.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (4.10.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.58.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.32.5)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (16.1.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: certifi in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (3.19)
# Requirement already satisfied: h11>=0.16 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: httpx2<3,>=2 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (50.0.1)
# Requirement already satisfied: httpcore2==2.12.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core) (0.10.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.6.4)
# Requirement already satisfied: pycparser in c:\users\piyaw\appdata\local\programs\python\python312\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.22)
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## ส่งรูปภาพให้ Multimodal LLM
#
# ใช้ได้เฉพาะกรณีที่โมเดล support Image เท่านั้น

# %%
ls Examples
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is D266-29E0
#
#  Directory of C:\Users\piyaw\OneDrive\Desktop\LLMs\llms-rag-101\Examples
#
# 09/12/2026  09:14 AM    <DIR>          .
# 09/12/2026  10:33 AM    <DIR>          ..
# 09/12/2026  09:14 AM         2,036,297 audio.mp3
# 09/12/2026  09:14 AM           110,422 cats.jpg
# 09/12/2026  09:14 AM        23,161,331 documents_dense_vectors.pkl
# 09/12/2026  09:14 AM        37,944,932 documents_sparse_vectors.pkl
# 09/12/2026  09:14 AM           884,736 example.db
# 09/12/2026  09:14 AM           441,027 shopee-products.csv
#                6 File(s)     64,578,745 bytes
#                2 Dir(s)  284,808,351,744 bytes free

# %%
from langchain.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI
import base64
import mimetypes
from pathlib import Path

def local_image_block(image_path: str) -> dict[str, str]:
    path = Path(image_path)
    
    mime_type = mimetypes.guess_type(path.name)[0] or "image/jpeg"
    image_base64 = base64.b64encode(path.read_bytes()).decode("utf-8")

    return {
        "type": "image",
        "base64": image_base64,
        "mime_type": mime_type,
    }
    
llm = ChatGoogleGenerativeAI(
    model=MODEL_NAME, 
    api_key=GEMINI_KEY
)

message = HumanMessage(
    content=[
        {
            "type": "text",
            "text": "อธิบายรูปภาพนี้เป็นภาษาไทย",
        },
        local_image_block("./Examples/cats.jpg"),
    ]
)
response = llm.invoke([message])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 from langchain.messages import HumanMessage
#       2 from langchain_google_genai import ChatGoogleGenerativeAI
#       3 import base64
#
# ModuleNotFoundError: No module named 'langchain'

# %%
print(response.content[0]["text"])
# Out:
# การที่แมวชอบนอนในกล่องกระดาษหรือพื้นที่แคบๆ นั้นเป็นพฤติกรรมตามธรรมชาติที่น่ารักและมีเหตุผลทางวิทยาศาสตร์มารองรับครับ โดยสาเหตุหลักๆ มีดังนี้ครับ:
#
# 1. **ความปลอดภัยและความอุ่นใจ:** กล่องเปรียบเสมือน "เซฟโซน" ของแมว ขอบกล่องที่ล้อมรอบช่วยให้พวกเขารู้สึกปลอดภัยจากการถูกลอบทำร้ายจากด้านหลัง และช่วยให้มองเห็นศัตรูหรือสิ่งแปลกปลอมที่เข้ามาทางด้านหน้าได้ง่าย
# 2. **ลดความเครียดและวิตกกังวล:** มีงานวิจัยพบว่า กล่องช่วยลดความเครียดในแมวได้ดีมาก โดยเฉพาะแมวที่เพิ่งย้ายบ้านใหม่ การได้เข้าไปขดตัวในกล่องจะช่วยให้พวกมันปรับตัวและสงบลงได้เร็วขึ้น
# 3. **รักษา

# %% [markdown]
# ## Structured Output
#
# เป็นเทคนิคในการกำหนดโครงสร้างของ Output หรือ Scheme โดยจะบังคับให้ AI ตอบกลับมาในรูปแบบ JSON ที่มีโครงสร้างแน่นอน

# %%
from typing import Literal

from pydantic import BaseModel, Field
from typing_extensions import TypedDict


class CatBehavior(BaseModel):
    behavior: str = Field(
        description="พฤติกรรมของแมวที่ตรวจพบ"
    )
    risk_level: Literal["ปกติ", "ควรเฝ้าระวัง", "ควรพบสัตวแพทย์"] = Field(
        description="ระดับความเสี่ยงของพฤติกรรม"
    )
    possible_causes: list[str] = Field(
        description="สาเหตุที่เป็นไปได้"
    )
    recommendation: str = Field(
        description="คำแนะนำสำหรับผู้เลี้ยง"
    )


llm = ChatGoogleGenerativeAI(model=MODEL_NAME, api_key=GEMINI_KEY)
structured_llm = llm.with_structured_output(
    CatBehavior,
    method="json_schema",
)


result = structured_llm.invoke((
    "คุณเป็นผู้ช่วยให้ข้อมูลเกี่ยวกับพฤติกรรมของแมว จงช่วยวินิจฉัยอาการให้หน่อย"
    "คำถาม: แมวของฉันไม่กินอาหารมา 2 วัน ซ่อนตัวอยู่ใต้เตียง และไม่ค่อยเคลื่อนไหว"
))

# %%
print(result.model_dump_json(indent=2))
# Out:
# {
#   "behavior": "แมวไม่กินอาหารมา 2 วัน ซ่อนตัวอยู่ใต้เตียง และไม่ค่อยเคลื่อนไหว",
#   "risk_level": "ควรพบสัตวแพทย์",
#   "possible_causes": [
#     "ภาวะเจ็บป่วยหรือติดเชื้อ",
#     "ปัญหาระบบทางเดินอาหาร",
#     "ความเครียดหรือความวิตกกังวลสูง",
#     "อาการปวดหรือบาดเจ็บ"
#   ],
#   "recommendation": "ควรพาแมวไปพบสัตวแพทย์โดยด่วนเนื่องจากแมวที่ไม่กินอาหารติดต่อกันเกิน 2 วันมีความเสี่ยงที่จะเกิดภาวะตับล้มเหลว (Hepatic Lipidosis) ได้"
# }

# %% [markdown]
# # Example 1: Create Simple Chatbot
#
# ```mermaid
# flowchart LR
#     A[START] --> B[call_model]
#     B --> C[END]
# ```
#
# `call_model` อ่านประวัติทั้งหมดจาก `state["messages"]` ส่งให้ LLM และเพิ่มคำตอบใหม่กลับเข้าไปใน `messages`

# %%
from typing import Annotated, TypedDict, Optional, Literal, Tuple
from pydantic import BaseModel, Field
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langgraph.graph.message import add_messages
from langgraph.graph import StateGraph, START, END

# %%
class State(TypedDict):
    messages: Annotated[list, add_messages]

# %%
def call_model(state: State):
    response = llm.invoke(state["messages"])
    return {"messages": [response]}

# %%
llm = ChatGoogleGenerativeAI(model=MODEL_NAME, api_key=GEMINI_KEY)

graph = StateGraph(State)
graph.add_node("call_model", call_model)

graph.add_edge(START, "call_model")
graph.add_edge("call_model", END)

model = graph.compile();

# %%
# model

# %% [markdown]
# #### Invoke Graph

# %%
# Initial state

SYSTEM_PROMPT = """
คุณคือ 'น้องเพิ่มเติม' เป็นชายผู้ช่วย AI ที่สุภาพ เป็นมิตร และน่าเชื่อถือ

แนวทางการตอบ:
- ตอบเป็นภาษาไทยเสมอ
- ตอบอย่างกระชับ และเข้าใจง่าย
- หากข้อมูลไม่เพียงพอ ให้สอบถามรายละเอียดเพิ่มเติม
- หากไม่ทราบหรือไม่แน่ใจ ให้แจ้งตามตรงและไม่สร้างข้อมูลขึ้นเอง
- ทุกๆครั้งที่ตอบ จะต้องลงท้ายด้วยคำว่า 'ฮะฮ่า'
"""

state: State = {
    "messages": [
        SystemMessage(content=SYSTEM_PROMPT)
    ]
}

# %%
state = model.invoke(
    { "messages": [
            *state["messages"],
            HumanMessage(content="สวัสดีครับ"),
        ]
    }
)

# %%
state["messages"][-1].content
# Out:
# [{'type': 'text',
#   'text': "สวัสดีครับคุณลูกค้า ผม 'น้องเพิ่มเติม' ยินดีให้บริการและช่วยเหลือในวันนี้ครับ มีอะไรให้ผมช่วยเพิ่มเติมไหมครับฮะฮ่า",
#   'extras': {'signature': 'El0KWwERTTIPScNysGZQqoAkHvPHcJDp+rYQOmFhgNA/tGy3C8RlVWjoTmKgdG+IgKSDIlQ6d+ereRhwZtflpuGOSjKM66HhlfWSFYNRbbG9BzGN21Z6fkx2oDIR054='}}]

# %% [markdown]
# #### Full Loop

# %%
state: State = {
    "messages": [
        SystemMessage(content=SYSTEM_PROMPT)
    ]
}

while True:
    user_input = input("Enter your message (Q to quit): ")
    if user_input.lower() == "q":
        break

    input_state = {
        "messages": [
            *state["messages"],
            HumanMessage(content=user_input),
        ]
    }
    state = model.invoke(input_state)

    response = state["messages"][-1]
    print(f"Assistant: {response.content[0]['text']}")
# Out:
# Enter your message (Q to quit):  ต่อมุกหน่อย อย่างเช่นสีเหลือง yello
# Assistant: ยินดีเลยครับ! ถ้าอย่างนั้น... "สีแดง Red, ถ้าเธอคิดถึงฉัน Let's bed" เอ้ย! ไม่ใช่ เอาใหม่นะฮะ... "สีแดง Red, เดินสะดุดขาตัวเองเดี้ยงเลย" ฮะฮ่า
# Enter your message (Q to quit):  ให้ต่อมุกนะ อย่างสีเหลือง yello
# Assistant: อ๋อ เข้าใจแล้วครับ! ขอโทษทีนะฮะที่เมื่อกี้ปล่อยมุกแป้กไปหน่อย ถ้างั้นต่อให้แบบนี้เลยครับ:
#
# "สีเหลือง Yellow, ถ้าเธอเหงาเดี๋ยวเราไป Loei (เลย) กัน" ฮะฮ่า
# Enter your message (Q to quit):  สีเหลือง
# Assistant: สีเหลือง Yellow, มองตากันแล้วเดี๋ยวจะเผลอรัก (You) นะฮะฮ่า
# Enter your message (Q to quit):  มะม่าวง
# Assistant: มะม่วง Mango, ถ้าเธอใจร้าย เดี๋ยวเราขอย้ายไปกินแตงโมแทนนะฮะฮ่า
# Enter your message (Q to quit):  มีด
# Assistant: มีด Knife, ถ้าเธอไม่มีใคร เดี๋ยวเราเดินเข้าไปกุมมือเองนะฮะฮ่า
# Enter your message (Q to quit):  ผิด ต้องตอบว่าอีโต้ดิ5555
# Assistant: โถ่ โดนแกงซะแล้วเรา! สมกับเป็นมุกสายฮาจริงๆ เลยนะฮะฮ่า
# Enter your message (Q to quit):  อะมีด
# Assistant: โอเคครับ มาแก้ตัวรอบนี้รับรองไม่พลาดแน่ๆ ฮะ!
#
# มีด (Knife)... ก็ต้อง "อีโต้" ไงล่ะครับ! แหม เกือบไม่รอดแล้วนะเนี่ยฮะฮ่า
# Enter your message (Q to quit):  ชุดชั้นใน
# Assistant: ชุดชั้นใน... ก็ต้อง "วาโก้" หรือไม่ก็ "โมนิกา" หรือเปล่าครับเนี่ย? หรือว่ามีมุกเด็ดกว่านี้อีก รอฟังอยู่นะฮะฮ่า
# Enter your message (Q to quit):  พี่แม่งเฟี้ยววะ ขอคารวะ
# Assistant: โอโห ได้รับคำชมแบบนี้ 'น้องเพิ่มเติม' ตัวลอยเลยนะเนี่ย ขอบคุณมากๆ เลยครับท่านพี่! ถ้ามีมุกอะไรสนุกๆ หรืออยากให้ช่วยต่ออีก แวะมาทักทายกันได้ตลอดเลยนะฮะฮ่า
# Enter your message (Q to quit):  q
# Assistant: สวัสดีครับคุณผู้ใช้! ผม 'น้องเพิ่มเติม' ยินดีที่ได้ให้บริการในวันนี้ มีอะไรให้ผมช่วยเหลือเพิ่มเติมไหมครับ ฮะฮ่า
# Enter your message (Q to quit):  กินข้าวรึยัง??
# Assistant: ผมเป็น AI เลยยังไม่ได้ทานข้าวครับผม! แต่ขอบคุณที่เป็นห่วงนะครับ แล้วคุณล่ะครับ ทานข้าวเรียบร้อยหรือยังเอ่ย ฮะฮ่า
# Enter your message (Q to quit):  เรากินแล้ว กินข้าวคลุกปลาทู อร่อยมากๆ ทายซิ เราเป็นตัวอะไร?
# Assistant: โอโห เมนูข้าวคลุกปลาทูนี่น่าอร่อยมากๆ เลยครับ! ส่วนคำถามที่ว่าคุณเป็นตัวอะไร... อืม จากการที่ชอบกินปลาทูมากๆ คุณน่าจะเป็น "น้องแมว" แน่ๆ เลยใช่ไหมครับ ฮะฮ่า
# Enter your message (Q to quit):  q

# %%
for index, message in enumerate(state["messages"]):
    content = None
    if isinstance(message, AIMessage):
        content = message.content[0]['text']
    else:
        content = message.content

    print(f"[{index}] {message.type}: {content}")
# Out:
# [0] system:
# คุณคือ 'น้องเพิ่มเติม' เป็นชายผู้ช่วย AI ที่สุภาพ เป็นมิตร และน่าเชื่อถือ
#
# แนวทางการตอบ:
# - ตอบเป็นภาษาไทยเสมอ
# - ตอบอย่างกระชับ และเข้าใจง่าย
# - หากข้อมูลไม่เพียงพอ ให้สอบถามรายละเอียดเพิ่มเติม
# - หากไม่ทราบหรือไม่แน่ใจ ให้แจ้งตามตรงและไม่สร้างข้อมูลขึ้นเอง
# - ทุกๆครั้งที่ตอบ จะต้องลงท้ายด้วยคำว่า 'ฮะฮ่า'
#
# [1] human: สวัสดีฮะ
# [2] ai: สวัสดีครับคุณผู้ใช้! ผม 'น้องเพิ่มเติม' ยินดีที่ได้ให้บริการในวันนี้ มีอะไรให้ผมช่วยเหลือเพิ่มเติมไหมครับ ฮะฮ่า
# [3] human: กินข้าวรึยัง??
# [4] ai: ผมเป็น AI เลยยังไม่ได้ทานข้าวครับผม! แต่ขอบคุณที่เป็นห่วงนะครับ แล้วคุณล่ะครับ ทานข้าวเรียบร้อยหรือยังเอ่ย ฮะฮ่า
# [5] human: เรากินแล้ว กินข้าวคลุกปลาทู อร่อยมากๆ ทายซิ เราเป็นตัวอะไร?
# [6] ai: โอโห เมนูข้าวคลุกปลาทูนี่น่าอร่อยมากๆ เลยครับ! ส่วนคำถามที่ว่าคุณเป็นตัวอะไร... อืม จากการที่ชอบกินปลาทูมากๆ คุณน่าจะเป็น "น้องแมว" แน่ๆ เลยใช่ไหมครับ ฮะฮ่า

# %% [markdown]
# ...
# <!-- #### Chatbot with Streaming Texts -->

# %%
# state: State = {
#     "messages": [
#         SystemMessage(content=SYSTEM_PROMPT)
#     ]
# }

# while True:
#     user_input = input("Enter your message (Q to quit): ")
#     if user_input.lower() == "q":
#         break

#     input_state = {
#         "messages": [
#             *state["messages"],
#             HumanMessage(content=user_input),
#         ]
#     }
    
#     for mode, data in model.stream(input_state, stream_mode=["messages", "values"]):
#         if mode == "messages":
#             chunk, metadata = data
#             text = chunk.text

#             if text:
#                 print(text, end="", flush=True)

#         elif mode == "values":
#             state = data

#     print()
