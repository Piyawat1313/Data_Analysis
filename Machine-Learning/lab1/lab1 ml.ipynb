# %%
from sklearn.datasets import load_diabetes 
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split

# %%
# diabets.dataset
load_diabet = load_diabetes()
x = load_diabet.data
y = load_diabet.target
print(x)
s = load_diabet.data.shape
print(s)

feature = load_diabet.feature_names
print(feature)
# Out:
# [[ 0.03807591  0.05068012  0.06169621 ... -0.00259226  0.01990749
#   -0.01764613]
#  [-0.00188202 -0.04464164 -0.05147406 ... -0.03949338 -0.06833155
#   -0.09220405]
#  [ 0.08529891  0.05068012  0.04445121 ... -0.00259226  0.00286131
#   -0.02593034]
#  ...
#  [ 0.04170844  0.05068012 -0.01590626 ... -0.01107952 -0.04688253
#    0.01549073]
#  [-0.04547248 -0.04464164  0.03906215 ...  0.02655962  0.04452873
#   -0.02593034]
#  [-0.04547248 -0.04464164 -0.0730303  ... -0.03949338 -0.00422151
#    0.00306441]]
# (442, 10)
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
# Ridge regression
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.99, random_state=0)

model = Ridge(alpha=0.01)
model.fit(X_train, y_train)

y_predic = model.predict(X_test)
mse = mean_squared_error(y_test, y_predic)
print(mse)
# Out:
# 4888.670272724388

# %%
# Lasso
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.99, random_state=0)

model = Lasso(alpha=0.1)
model.fit(X_train, y_train)

y_predic = model.predict(X_test)
mse = mean_squared_error(y_test, y_predic)
print(mse)
# Out:
# 4786.767534603021
# C:\Users\piyaw\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.642736e+00, tolerance: 3.081e+00
#   model = cd_fast.enet_coordinate_descent(

# %%
# Linear Regression
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.99, random_state=0)

model = LinearRegression()
model.fit(X_train, y_train)

y_predic = model.predict(X_test)
mse = mean_squared_error(y_test, y_predic)
print(mse)
# Out:
# 5151.025627144228

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.99, random_state=0)

model = ElasticNet(random_state=0)
model.fit(X_train, y_train)

y_predic = model.predict(X_test)
mse = mean_squared_error(y_test, y_predic)
print(mse)
# Out:
# 8250.969085867586

# %% [markdown]
# ## ถ้าเราจะดูว่าข้อมูลมีกี่ feature และ ข้อมูลมีจำนวนเท่าไร

# %%
s = load_diabet.data.shape

# %% [markdown]
# ## load_diabetes จะมีค่าอยู่ 2 ค่า

# %%
x = load_diabet.data
y = load_diabet.target

# %% [markdown]
# ## กรณีที่เราอยากรู้ว่า feature แต่ละอันที่อยู่ใน load_diabetes ชื่ออะไรบ้าง

# %%
feature = load_diabet.feature_names

# %% [markdown]
# ## ถ้าต้องการแบ่งข้อมูลเป็นการ Train และ Test

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.99, random_state=0)

# %% [markdown]
# ##### test_size --> ขนาดของข้อมูลในการ Test
# ##### random_state --> เป็นการควบคุมข้อมูลให้ออกแบบเดิมทุกครั้ง

# %% [markdown]
# ## วิธีการ Train model

# %%
model = LinearRegression()
model.fit(X_train, y_train)
